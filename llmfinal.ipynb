# %%
import numpy as np
import re
import pandas as pd
import spacy
import string
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
import nltk

# %%
nltk.data.path.append("/kaggle/input/nltk-data/nltk-data")

# %%
train_essays_df = pd.read_csv("/kaggle/input/llm-detect-ai-generated-text/train_essays.csv")
display(train_essays_df)

train_essays_df['generated'].value_counts()

train_essays_df[train_essays_df['generated']==1]
# Out:
#             id  prompt_id                                               text  \
# 0     0059830c          0  Cars. Cars have been around since they became ...
# 1     005db917          0  Transportation is a large necessity in most co...
# 2     008f63e3          0  "America's love affair with it's vehicles seem...
# 3     00940276          0  How often do you ride in a car? Do you drive a...
# 4     00c39458          0  Cars are a wonderful thing. They are perhaps o...
# ...        ...        ...                                                ...
# 1373  fe6ff9a5          1  There has been a fuss about the Elector Colleg...
# 1374  ff669174          0  Limiting car usage has many advantages. Such a...
# 1375  ffa247e0          0  There's a new trend that has been developing f...
# 1376  ffc237e9          0  As we all know cars are a big part of our soci...
# 1377  ffe1ca0d          0  Cars have been around since the 1800's and hav...
#
#       generated
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1373          0
# 1374          0
# 1375          0
# 1376          0
# 1377          0
#
# [1378 rows x 4 columns]
#             id  prompt_id                                               text  \
# 704   82131f68          1  This essay will analyze, discuss and prove one...
# 740   86fe4f18          1  I strongly believe that the Electoral College ...
# 1262  eafb8a56          0  Limiting car use causes pollution, increases c...
#
#       generated
# 704           1
# 740           1
# 1262          1

# %%
nlp = spacy.load("en_core_web_sm")
stop_words = nlp.Defaults.stop_words
punctuations = string.punctuation
print(stop_words)
print(punctuations)
# Out:
# {'doing', 'still', 'upon', 'many', 'everywhere', 'at', 'whereby', 'several', 'somehow', 'less', 'everyone', 'via', 'yourselves', '‘m', 'nine', 'twenty', 'anywhere', 'when', 'were', 'anyway', 'therefore', 're', 'along', 'otherwise', 'had', 'using', 'whether', 'could', 'n’t', 'however', 'are', 'another', 'except', 'us', 'ours', '‘s', 'them', 'seeming', 'who', 'towards', 'into', '’d', 'seems', 'made', 'nothing', "'re", 'make', 'here', 'used', 'some', "n't", 'in', 'thereby', 'full', 'most', 'yet', 'hereafter', 'never', 'none', 'because', 'myself', 'besides', 'around', 'really', 'thereafter', 'show', 'move', 'thus', '’re', 'has', 'by', 'hereby', 'take', 'over', 'during', 'namely', 'third', 'formerly', 'thereupon', 'once', 'now', 'being', 'n‘t', 'same', 'above', 'perhaps', 'so', 'something', 'somewhere', 'every', 'six', 'else', 'well', 'hereupon', 'hence', '‘d', 'cannot', 'always', 'you', 'per', 'must', 'became', 'see', 'hundred', '‘ve', 'both', 'until', 'give', 'was', 'than', 'wherein', 'front', 'own', 'ca', 'four', 'everything', 'nobody', 'their', 'someone', 'and', 'therein', 'may', 'together', '‘re', "'m", 'mostly', 'whither', 'off', 'yours', 'been', "'s", 'whose', 'an', 'rather', 'our', '’m', 'should', 'others', 'beforehand', 'amongst', '‘ll', 'ourselves', 'just', 'be', 'due', 'whom', 'he', 'she', 'without', 'those', 'themselves', 'have', 'they', 'no', '’ll', 'one', '’ve', 'though', 'beside', 'eleven', 'other', 'latterly', 'all', 'more', 'throughout', 'your', 'former', 'himself', 'alone', 'unless', 'itself', 'various', 'which', 'from', 'last', 'did', 'but', 'the', 'to', 'since', 'do', 'ten', 'please', 'am', 'not', 'sometimes', 'even', 'wherever', 'latter', 'two', 'say', 'whoever', 'much', 'neither', 'whence', 'either', 'call', 'is', 'while', 'onto', 'nevertheless', 'forty', 'under', 'herein', 'further', 'fifty', 'next', 'these', 'name', 'elsewhere', 'anyone', 'regarding', 'again', 'become', 'sixty', 'least', 'its', "'d", 'whenever', "'ve", 'eight', 'meanwhile', 'might', 'already', 'top', 'herself', 'my', 'anything', 'first', 'where', 'mine', 'seem', 'three', 'through', 'few', 'for', 'side', 'sometime', 'thence', 'behind', 'as', 'on', 'put', 'twelve', 'i', 'part', 'a', 'nowhere', 'anyhow', 'whereupon', 'if', 'with', 'enough', 'thru', 'almost', 'it', 'serious', 'toward', 'back', 'or', 'of', 'afterwards', 'keep', 'why', 'nor', 'up', 'becomes', 'there', 'against', 'seemed', 'out', 'whole', 'too', 'bottom', 'below', 'beyond', 'his', 'before', 'me', 'after', 'him', 'about', 'only', 'empty', 'get', 'each', 'does', 'how', 'between', 'amount', 'that', 'although', 'quite', 'yourself', 'within', 'can', 'this', 'would', 'done', 'such', 'very', 'moreover', 'her', "'ll", 'hers', 'fifteen', 'noone', 'any', 'down', 'also', 'go', 'will', 'indeed', 'across', '’s', 'we', 'ever', 'whereas', 'becoming', 'five', 'whatever', 'often', 'among', 'whereafter', 'what', 'then'}
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def clean_text(text):
    doc = nlp(text.lower().strip())
    tokens = [word.lemma_ for word in doc if word.text not in stop_words and word.text not in punctuations]
    return " ".join(tokens)

# %%
train_essays_df['cleaned_text'] = train_essays_df['text'].apply(clean_text)

# %%
X = train_essays_df['cleaned_text']
y = train_essays_df['generated']
tfidf = TfidfVectorizer(max_features=5000, min_df=3, max_df=0.7, ngram_range=(1, 2))
X_tfidf = tfidf.fit_transform(X)

# %%
X_tfidf_shuffled, y_shuffled = shuffle(X_tfidf, y, random_state=42)

# %%
model = SVC(probability=True)
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
clf = GridSearchCV(model, parameters, cv=5)

# Fit and Tune Model
clf.fit(X_tfidf_shuffled, y_shuffled)
print("Best Parameters:", clf.best_params_)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# Best Parameters: {'C': 1, 'kernel': 'linear'}

# %%
skf = StratifiedKFold(n_splits=5)
accuracies = []
for train_index, test_index in skf.split(X_tfidf_shuffled, y_shuffled):
    X_train, X_test = X_tfidf_shuffled[train_index], X_tfidf_shuffled[test_index]
    y_train, y_test = y_shuffled.iloc[train_index], y_shuffled.iloc[test_index]

    model.set_params(**clf.best_params_)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracies.append(accuracy_score(y_test, y_pred))

print("Average accuracy:", np.mean(accuracies))
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# Average accuracy: 0.9978260869565216

# %%
test_df = pd.read_csv('/kaggle/input/llm-detect-ai-generated-text/test_essays.csv')
test_df['cleaned_text'] = test_df['text'].apply(clean_text)
test_tfidf = tfidf.transform(test_df['cleaned_text'])

# %%
submit = pd.read_csv('/kaggle/input/llm-detect-ai-generated-text/sample_submission.csv')
submit['generated'] = model.predict_proba(test_tfidf)[:,1]

submit.to_csv('submission.csv', index=False)

# %%
submit.head()
# Out:
#          id  generated
# 0  0000aaaa   0.007287
# 1  1111bbbb   0.007287
# 2  2222cccc   0.007287

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Non-Generated', 'Generated'], yticklabels=['Non-Generated', 'Generated'])
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, test_scores = learning_curve(model, X_tfidf_shuffled, y_shuffled, cv=5)
train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_scores_mean, label='Training score')
plt.plot(train_sizes, test_scores_mean, label='Cross-validation score')
plt.xlabel('Training Set Size')
plt.ylabel('Accuracy Score')
plt.title('Learning Curve')
plt.legend(loc='best')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
